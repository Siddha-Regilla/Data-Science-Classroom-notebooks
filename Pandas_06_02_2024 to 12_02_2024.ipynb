# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddha-Regilla/Data-Science-Classroom-notebooks/blob/main/Pandas_06_02_2024%20to%2012_02_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Science2 - Day 6 - 06-02-2024

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # for visualizations
import seaborn as sns # for visualizations
import warnings

# %%
#Importing functions from the above library
warnings.filterwarnings('ignore')

# %% [markdown]
# # ***06-02-2024***

# %%
#we can upload the file by selecting the folder icon on the left and selecting the upload button and locate file on the system

# %%
#reading the file and storing it in a variable
df=pd.read_csv('Salaries.csv')

# %%
#To see the contents of the file
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#First few records (default is 5 unless a value is specified in the ()) - .head()
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#Last few records (default is 5 unless a value is specified in the ()) - .tail()
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
#df.shape gives the no. of rows and no. of columns. It is a feature. Therefore, () are not used
df.shape
# Out:
# (78, 6)

# %%
#Gives names of the columns. Also a feature of the dataframe. df.columns
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
#Gives the datatypes of each columns. Also a feature
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
#Information about data - total no. of observations, range of observations, no. of columns, how many non-null observations, and the dtypes of the columns
#It is a function
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
#shows if there are any null values
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
#setting pandas such that all the records are displayed
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
#It is going to confirm by saying there are no null values in the dataset by giving us the sum of all null values in a particular column
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
#It will work on the numerical columns and gives the count of obs., mean, std, min, Q1, Q3, max
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
#It gives the values present in that particular column mentioned
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
# 30    107008
# 31    155750
# 32    103275
# 33    120000
# 34    119800
# 35    126933
# 36    146856
# 37    102000
# 38     91000
# 39    129000
# 40    137000
# 41     74830
# 42     80225
# 43     77000
# 44    151768
# 45    140096
# 46     74692
# 47    103613
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# ...

# %%
#Applying the mean function on the specific column
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
#Applying the median function on the specific column
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427907

# %%
df['salary'].std()
# Out:
# 28293.66102226417

# %%
df['salary'].min()
# Out:
# 57800

# %%
df['salary'].max()
# Out:
# 186960

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df['salary'].kurt()
# Out:
# -0.4017126758820546

# %%
df[['salary','service']].mean()
# Out:
# salary     108023.782051
# service        15.051282
# dtype: float64

# %%
df.mean()
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
#This gives a output weather the record is more than 1,20,000 or not
df['salary']>120000
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27     True
# 28    False
# 29     True
# 30    False
# 31     True
# 32    False
# 33    False
# 34    False
# 35     True
# 36     True
# 37    False
# 38    False
# 39     True
# 40     True
# 41    False
# 42    False
# 43    False
# 44     True
# 45     True
# 46    False
# 47    False
# 48    False
# 49     True
# 50    False
# 51     True
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58     True
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70    False
# ...

# %%
#To see the value of records with salary more than 1,20,000
df[df['salary']>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
#Tells us the structure of the data
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Gives the maximum value in a certain column
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
#It gives the count of a unique value within a column
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %% [markdown]
# # ***12-02-2024***

# %%
# imported matplotlib and seaborn for visualizations

# %% [markdown]
# upload the Universities.csv file

# %%
df1 =pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#Creating a histogram plot for Acceptance column
plt.hist(df1['Accept'])
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
#So that we dont see any of the written values
plt.hist(df1['Accept'])
plt.xlabel('Acceptance')
plt.ylabel('Count')
plt.title('Histogram of Acceptance')
plt.figure(figsize=(5,5))
plt.show()

# %%
# For SAT column
plt.hist(df1['SAT'])
plt.xlabel('SAT score')
plt.ylabel('Count')
plt.title('Histogram of SAT score')
plt.figure(figsize=(5,5))
plt.show()

# %%
#Using Seaborn library - it has better visualizations and more options of plots
# Histogram using Seaborn library
sns.histplot(df1['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
sns.histplot(df1['SAT'])
plt.xlabel('SAT score')
plt.ylabel('Count')
plt.title('Histogram of SAT score')
plt.figure(figsize=(5,5))
plt.show()

# %%
#Creating a distribution plot
sns.distplot(df1['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
#Creating a scatter plot
plt.plot(df1['Accept'],df1['Expenses'],'r*') # the 'bo' indicates blue circles, 'r+' indicates red +, y* indicates yellow *, and so on
plt.xlabel('Acceptance')
plt.ylabel('Expenses')
plt.title('Scatter plot - Acceptance vs Expenses')
plt.show()

# %%
#To understand any code write help and in () write the code or function you need to understand
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
#Combining both histogram and scatter plot
sns.pairplot(df1)

# %%
#Understanding iloc function
#Type 1
df1.iloc[:,:] # all the rows and columns
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#Type 2
df1.iloc[0:10,:] # 1st 10 records (starting from 0th index uptil 9th index and all columns)
# Out:
#            Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0         Brown  1310     89      22       13     22704        94
# 1       CalTech  1415    100      25        6     63575        81
# 2           CMU  1260     62      59        9     25026        72
# 3      Columbia  1310     76      24       12     31510        88
# 4       Cornell  1280     83      33       13     21864        90
# 5     Dartmouth  1340     89      23       10     32162        95
# 6          Duke  1315     90      30       12     31585        95
# 7    Georgetown  1255     74      24       12     20126        92
# 8       Harvard  1400     91      14       11     39525        97
# 9  JohnsHopkins  1305     75      44        7     58691        87

# %%
#Type 3
df1.iloc[0:10,0:3] #1st 10 records and 1st 3 columns (starting from 0th index uptil 9th index for rows and starting from 0th index to 2nd index for columns)
# Out:
#            Univ   SAT  Top10
# 0         Brown  1310     89
# 1       CalTech  1415    100
# 2           CMU  1260     62
# 3      Columbia  1310     76
# 4       Cornell  1280     83
# 5     Dartmouth  1340     89
# 6          Duke  1315     90
# 7    Georgetown  1255     74
# 8       Harvard  1400     91
# 9  JohnsHopkins  1305     75

# %%
#Type 4
df1.iloc[0:10,[0,2,5]] #1st 10 records (starting from 0th index uptil 9th index) and only the specified number index columns
# Out:
#            Univ  Top10  Expenses
# 0         Brown     89     22704
# 1       CalTech    100     63575
# 2           CMU     62     25026
# 3      Columbia     76     31510
# 4       Cornell     83     21864
# 5     Dartmouth     89     32162
# 6          Duke     90     31585
# 7    Georgetown     74     20126
# 8       Harvard     91     39525
# 9  JohnsHopkins     75     58691

# %%
#Using the above iloc function we can further use pairplot as follows -
sns.pairplot(df1.iloc[:,1:4])

# %%
#Creating a box plot
plt.boxplot(df1['Accept'])
plt.show()

# %%
plt.boxplot(df1['SAT'])
plt.show()

# %%
#To understand the min,max, count, mean, std, 25%Q, 50%Q, 75%Q
df1.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
df1['Accept'].describe()
# Out:
# count    25.000000
# mean     39.200000
# std      19.727308
# min      14.000000
# 25%      24.000000
# 50%      36.000000
# 75%      50.000000
# max      90.000000
# Name: Accept, dtype: float64

# %%
#To plot a horizontal box plot
plt.boxplot(df1['Accept'],vert=False)
plt.show()

# %% [markdown]
# Using and understanding Numpy library

# %%
#import the numpy library

# %%
# Creating an array
a=np.array([1,2,3,4])

# %%
# Printing an array
print(a)
# Out:
# [1 2 3 4]

# %%
#It tells us that it is a numpy array
type(a)
# Out:
# numpy.ndarray

# %%
# No. of elements in an array
a.size
# Out:
# 4

# %%
# 1 dimension array
a.shape
# Out:
# (4,)

# %%
# 2 dimension array
df1.shape
# Out:
# (25, 7)

# %%
# minimum value
a.min()
# Out:
# 1

# %%
# maximum value

a.max()
# Out:
# 4

# %%
#Addition of all values in a list
a.sum()
# Out:
# 10

# %%
#Product of all values in a list
a.prod()
# Out:
# 24

# %%
# Creating a 2 dimensional array
b=np.array([(1,2,3,4),(4,5,6,7)])

# %%
print(b)
# Out:
# [[1 2 3 4]
#  [4 5 6 7]]

# %%
#2 rows, 4 columns
b.shape
# Out:
# (2, 4)

# %%
b.size
# Out:
# 8

# %%
#Reshaping the array such that it has 4 rows and 2 columns
c=b.reshape(4,2)

# %%
c
# Out:
# array([[1, 2],
#        [3, 4],
#        [4, 5],
#        [6, 7]])

# %%
c.shape
# Out:
# (4, 2)

# %%
c[0][0]
# Out:
# 1

# %%
#Gives the minimum value for the specified index row
c[1].min()
# Out:
# 3

# %%
#For row-wise calculations axis=0; i.e, (1+3+4+6),(2+4+5+7)
c.sum(axis=0)
# Out:
# array([14, 18])

# %%
#For column-wise calculations axis=1; i.e, (1+2),(3+4),(4+5),(6+7)
c.sum(axis=1)
# Out:
# array([ 3,  7,  9, 13])

# %% [markdown]
# Dataframes

# %%
#Creating a dataframe
df2 = pd.DataFrame({'Col 1':['A','A','B','B','B'],
                    'Col 2':[2,2,2,3,3]})

# %%
df2
# Out:
#   Col 1  Col 2
# 0     A      2
# 1     A      2
# 2     B      2
# 3     B      3
# 4     B      3

# %% [markdown]
# How to handle duplicates

# %%
#Identify duplicates
df2.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
#Checking those duplicated records
df2[df2.duplicated()]
# Out:
#   Col 1  Col 2
# 1     A      2
# 4     B      3

# %%
#Dropping the duplicates
df3=df2.drop_duplicates()

# %%
df3
# Out:
#   Col 1  Col 2
# 0     A      2
# 2     B      2
# 3     B      3

# %%
#Rearranging the dataframe to reflect the updated indexes
df4=df3.reset_index()

# %%
df4
# Out:
#    index Col 1  Col 2
# 0      0     A      2
# 1      2     B      2
# 2      3     B      3

# %%
#Removing the index column showing the old indexes
df5=df4.drop('index',axis=1)

# %%
df5
# Out:
#   Col 1  Col 2
# 0     A      2
# 1     B      2
# 2     B      3

# %% [markdown]
# Some basic points on data structures

# %%
# Type 1 - List : We can add, remove, modify the values in the list
d=[1,2,3,4]
s=['a','b','c','d']
print(type(s),type(d))
# Out:
# <class 'list'> <class 'list'>

# %%
# Type 2 - Tuple : we can't make any changes to a tuple
e=(1,2,3,4)
type(e)
# Out:
# tuple

# %%
# Type 3 - Array
f=np.array([1,2,3,4])
type(f)
# Out:
# numpy.ndarray

# %%
# Type 4 - Dictionary : Includes key and value
g={1:'ExcelR',2:'Solutions',3:'Ltd'}
type(g)
# Out:
# dict
